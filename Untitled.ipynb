# %%
import pandas as pd

retirement_titles_to_load = 'Data/retirement_titles.csv'
retirement_titles_df = pd.read_csv(retirement_titles_to_load)
retirement_titles_df.head(25)
# Out:
#     emp_no first_name   last_name               title   from_date     to_date
# 0    10001     Georgi     Facello     Senior Engineer  1986-06-26  9999-01-01
# 1    10004  Chirstian     Koblick            Engineer  1986-12-01  1995-12-01
# 2    10004  Chirstian     Koblick     Senior Engineer  1995-12-01  9999-01-01
# 3    10005    Kyoichi    Maliniak        Senior Staff  1996-09-12  9999-01-01
# 4    10005    Kyoichi    Maliniak               Staff  1989-09-12  1996-09-12
# 5    10006     Anneke     Preusig     Senior Engineer  1990-08-05  9999-01-01
# 6    10009     Sumant        Peac  Assistant Engineer  1985-02-18  1990-02-18
# 7    10009     Sumant        Peac            Engineer  1990-02-18  1995-02-18
# 8    10009     Sumant        Peac     Senior Engineer  1995-02-18  9999-01-01
# 9    10011       Mary       Sluis               Staff  1990-01-22  1996-11-09
# 10   10018   Kazuhide        Peha            Engineer  1987-04-03  1995-04-03
# ...
